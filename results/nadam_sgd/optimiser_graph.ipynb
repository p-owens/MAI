# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
nadam_pd = pd.read_csv(os.getcwd() + "/ch19_training_log_nadam.csv")
sgd_pd = pd.read_csv(os.getcwd() + "/ch19_training_log_sgd.csv")
nadam = nadam_pd.to_numpy()
sgd = sgd_pd.to_numpy()
file_ext = 'pdf'

# %%
nadam_pd
# Out:
#      epoch      loss  mean_absolute_percentage_error  r_squared  val_loss  \
# 0        0  2.572452                    6.159924e+06 -13.308706  1.420125
# 1        1  1.602273                    2.258735e+07  -8.073401  0.349242
# 2        2  1.236870                    3.578565e+07  -5.997233  0.386174
# 3        3  1.066002                    3.390765e+07  -4.892276  0.436040
# 4        4  0.973970                    3.891363e+07  -4.821458  0.505063
# ..     ...       ...                             ...        ...       ...
# 745    745  0.022606                    1.612990e+05   0.871703  0.006149
# 746    746  0.022058                    1.163201e+05   0.874168  0.004957
# 747    747  0.021504                    6.009349e+00   0.881576  0.005469
# 748    748  0.022688                    9.111485e+04   0.875841  0.005618
# 749    749  0.021616                    6.189381e+04   0.881334  0.005679
#
#      val_mean_absolute_percentage_error  val_r_squared
# 0                          9.937186e+06     -13.409929
# 1                          2.644368e+07      -2.246802
# 2                          2.547638e+07      -2.691126
# 3                          2.506421e+07      -3.234945
# 4                          2.469517e+07      -3.966037
# ..                                  ...            ...
# 745                        2.524881e+00       0.944841
# 746                        2.253128e+00       0.956850
# 747                        2.390430e+00       0.952066
# 748                        2.424679e+00       0.950845
# 749                        2.404633e+00       0.950177
#
# [750 rows x 7 columns]

# %%
fig, ax = plt.subplots(1, figsize = (12,8))

plt.plot(nadam[:,0], nadam[:,1], label='Nadam')

plt.plot(sgd[:,0], sgd[:,1], label='SGD')



title = 'SGD v Nadam, Ch 19 Training Log'
ax.set_title(title)
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss: Mean Squared Error')


ax.set_ylim([0, 2.6])
plt.legend(loc="best")
plt.show()

fig.savefig('images/{0}.{1}'.format(title,file_ext))

# %%
fig = plt.figure(figsize = (10,6))
a1 = fig.add_axes([0,0,1,1])

a1.plot(nadam[:,0], nadam[:,1], label='Mean Squared Error', color='tab:blue')

a2 = a1.twinx()
a2.plot(nadam[:,0], nadam[:,2], label='Mean Absolute Percentage Error', color='tab:orange')

a1.set_ylim([0, 2.7])
a2.set_ylim([0, 5.6e7])


title = 'Loss Function Comparison, Mean Squared Error v Mean Absolute Percentage Error'
a1.set_title(title)
a1.set_xlabel('Epochs')
a1.set_ylabel('Loss: Mean Squared Error')
a2.set_ylabel('Loss: Mean Absolute Percentage Error')

fig.legend(labels = ('Mean Squared Error','Mean Absolute Percentage Error'),loc='upper right', bbox_to_anchor=(0.99, 0.99))
plt.show()

fig.savefig('images/{0}.{1}'.format(title,file_ext))

# %%
fig2, ax2 = plt.subplots(1, figsize = (10,6))

plt.plot(nadam[:,0], nadam[:,1], label='Training Loss')

plt.plot(nadam[:,0], nadam[:,4], label='Validation Loss')


ax2.set_ylim([0, 2.65])

title = 'Channel 19 Training Log'
ax2.set_title(title)
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Loss: Mean Squared Error')

plt.legend(loc="best")
plt.show()

fig2.savefig('images/{0}.{1}'.format(title,file_ext))

# %%
fig2, ax2 = plt.subplots(1, figsize = (10,6))

plt.plot(nadam[100:,0], nadam[100:,1], label='Training Loss')

plt.plot(nadam[100:,0], nadam[100:,4], label='Validation Loss')


ax2.set_ylim([0, 0.33])

title = 'Channel 19 Training Log'
ax2.set_title(title)
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Loss: Mean Squared Error')

plt.legend(loc="best")
plt.show()

fig2.savefig('images/{0}.{1}'.format(title+'inset',file_ext))
